# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
#td=pd.read_csv(r"C:\Users\GANESH\Downloads\svmfile.csv")

# %%
td.head()

# %%
td.isnull().sum()

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

# %%
td.job = le.fit_transform(td.job)

# %%
td.marital = le.fit_transform(td.marital)

# %%
td.education.unique()

# %%
td.education = td.education.replace({'illiterate':0,'unknown':0,'basic.4y':1,'basic.6y':2,'basic.9y':3,'high.school':4,'university.degree':5,'professional.course':6})

# %%
td.default = td.default.replace({'no':0,'unknown':1 ,'yes':2})
td.housing = td.housing.replace({'no':0,'unknown':1 ,'yes':2})
td.loan = td.loan.replace({'no':0,'unknown':1 ,'yes':2})



td.contact = le.fit_transform(td.contact)

# %%
td.dtypes

# %%
td.month.unique()

# %%
td.month = td.month.replace({'may':2, 'jun':3, 'jul':4, 'aug':5, 'oct':7, 'nov':8, 'dec':9, 'mar':0, 'apr':1, 'sep':6})

# %%
td.day_of_week = td.day_of_week.replace({'mon':1, 'tue':2, 'wed':3, 'thu':4, 'fri':5})

# %%
td.day_of_week.unique()

# %%
td.poutcome = td.poutcome.replace({'nonexistent':1, 'failure':2, 'success':3})

# %%
td.poutcome.unique()

# %%
td.columns

# %%
td.dtypes

# %%
td.head()

# %%
td=td.replace({'None': np.nan})

# %%
td.isnull().sum()

# %%
td.education=td.education.fillna(1)

# %%
##td.head()

# %%
##td.education.replace({'none':0},inplace=True)

# %%
 from sklearn.model_selection import train_test_split

# %%
td_train ,td_test = train_test_split(td , test_size = .2)

# %%
td_train_x = td_train.iloc[ : , 0:-1 ]
td_train_y = td_train.iloc[ : , -1 ]

# %%
td_test_x = td_test.iloc[ : , 0:-1 ]
td_test_y = td_test.iloc[ : , -1 ]

# %%
from sklearn.svm import SVC

# %%
svc_td = SVC()

# %%
svc_td.fit(td_train_x , td_train_y)
# Out:
# SVC()

# %%
pred_td = svc_td.predict(td_test_x)

# %%
pred_td
# Out:
# array(['no', 'no', 'no', ..., 'no', 'no', 'no'], dtype=object)

# %%
td_test_x.head()
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 31742   41    1        1          2        1        2     0        0      2
# 20042   31    4        2          5        0        2     0        0      5
# 15270   28    1        2          0        0        0     0        0      4
# 35627   32    0        1          5        0        2     2        0      2
# 7835    42    1        1          2        0        2     0        1      3
#
#        day_of_week  duration  campaign  pdays  previous  poutcome  \
# 31742            4       220         1    999         0         1
# 20042            1        72         1    999         0         1
# 15270            4        82         2    999         0         1
# 35627            1       110         1    999         1         2
# 7835             1      1036         1    999         0         1
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
tab_svm = confusion_matrix (td_test_y , pred_td)

# %%
tab_svm
# Out:
# array([[7213,  113],
#        [ 710,  202]], dtype=int64)
